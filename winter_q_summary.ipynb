# %% [markdown]
# # 26012018-09032018 winter quarter summary:

# %% [markdown]
# finding a linear relationship between initial velocity and [A.P] in tris

# %%
import csv
import sys
sys.path.insert(0, 'process_csv/')
from process_csv import *
import matplotlib.pyplot as plt
from scipy.stats import linregress
import requests
with open("dataset/winter_q_summary.csv") as file:
    reader=csv.reader(file)
    data=list(reader)
header=data[0]
i=0
j=1
csvdict={}
while i<len(data[j]):
    csvdict[header[i]]=[]
    while j<len(data):
        csvdict[header[i]].append(data[j][i])
        j+=1
    j=1
    i+=1
for key,val in csvdict.items():
    val=list(map(float, [a for a in val if a]))
    csvdict[key]=val
yval=[]
for i in csvdict[header[2]]:
    yval.append(i*60)
coordict={}
for a,b in zip(csvdict[header[1]],yval):
    #coordict[a]=b
    print(a, ",", b)    
plt.style.use('seaborn-whitegrid')
plt.xlabel("[A.P] in tris mg/mL")
plt.ylabel("initial velocity /min")
plt.title("A.P activity at various A.P concentrations")
plt.rcParams["figure.figsize"] = [20,12]
plt.rcParams.update({'font.size': 22})
plt.plot(csvdict[header[1]],yval,"o")
linregress(csvdict[header[1]],yval)
# Out:
# 2.5 , 2.832
# 0.5 , 0.792
# 0.25 , 0.2652
# 1.0 , 1.38
# 1.0 , 1.3199999999999998
# 0.5 , 0.84
# 0.5 , 0.6599999999999999
# 0.25 , 0.24
# 0.25 , 0.24
# 0.125 , 0.12
# 0.125 , 0.06
# LinregressResult(slope=1.1685323792486584, intercept=0.05177030411449013, rvalue=0.9868374550181053, pvalue=1.9780571770102056e-08, stderr=0.06383001919484708)
